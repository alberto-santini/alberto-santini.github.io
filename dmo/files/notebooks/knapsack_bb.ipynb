# %%
from dataclasses import dataclass
from typing import Iterable, List, Optional

# %%
@dataclass
class Knapsack:
    weight: Iterable[int]
    profit: Iterable[int]
    capacity: int

    def __len__(self):
        assert len(self.weight) == len(self.profit)
        return len(self.weight)
    
    def items(self) -> List[int]:
        return list(range(len(self)))


@dataclass
class KnapsackSolution:
    profit: int
    items: List[int]

    def __str__(self) -> str:
        return f"Profit = {self.profit}; Items = " + ', '.join(map(str, self.items))


@dataclass
class ContinuousKnapsackSolution:
    profit: float
    items_x: List[float]

    def integer(self) -> bool:
        return all(x.is_integer() for x in self.items_x)
    
    def items(self) -> List[int]:
        assert self.integer()
        return [j for j, x in enumerate(self.items_x) if x == 1.0]

# %%
class BBNode:
    kp: Knapsack
    fixed: List[int]
    free: List[int]
    parent_sol: Optional[ContinuousKnapsackSolution]

    def __init__(self, kp: Knapsack, fixed: List[int], free: List[int], parent_sol: Optional[ContinuousKnapsackSolution] = None):
        self.kp = kp
        self.fixed = fixed
        self.free = free
        self.parent_sol = parent_sol

    def solve(self) -> Optional[ContinuousKnapsackSolution]:
        capacity = self.kp.capacity - sum(self.kp.weight[j] for j in self.fixed)
        excluded = set(self.kp.items()) - set(self.fixed) - set(self.free)
        print(f"\tFixed: {', '.join(map(str, self.fixed))}")
        print(f"\tExcluded: {', '.join(map(str, excluded))}")
        print(f"\tFree: {', '.join(map(str, self.free))}")
        print(f"\tResidual capacity: {capacity}")

        if capacity < 0:
            return None
        
        if self.parent_sol is not None:
            # Determine which item was branched on to produce this B&B node
            if len(self.free) > 0:
                branching_item = min(self.free) - 1
            else:
                branching_item = len(self.kp) - 1

            # Check if we can apply the shortcut
            if (x := self.parent_sol.items_x[branching_item]) == 1.0:
                print(f"\tBranching item {branching_item} was selected in parent node (x = {x}): shortcutting.")
                return self.parent_sol

        profit = 0.0
        items_x = [0.0] * len(self.kp)

        for j in self.fixed:
            profit += self.kp.profit[j]
            items_x[j] = 1.0

        for j in self.free:
            if (w := self.kp.weight[j]) < capacity:
                profit += self.kp.profit[j]
                items_x[j] = 1.0
                capacity -= w
            else:
                items_x[j] = capacity / w
                break

        print(f"\tOptimal sol: " + ', '.join(f"{j}: {val}" for j, val in enumerate(items_x)))

        return ContinuousKnapsackSolution(profit=profit, items_x=items_x)

class BBTree:
    kp: Knapsack
    nodes: List[BBNode]
    best_solution: Optional[KnapsackSolution]

    def __init__(self, kp: Knapsack):
        self.kp = kp
        self.nodes = [self.__root_node()]
        self.best_solution = None

    def __root_node(self) -> BBNode:
        return BBNode(kp=self.kp, fixed=list(), free=self.kp.items(), parent_sol=None)
    
    def __update_best(self, sol: ContinuousKnapsackSolution) -> None:
        assert sol.integer()

        if self.best_solution is None or self.best_solution.profit < sol.profit:
            self.best_solution = KnapsackSolution(profit=sol.profit, items=sol.items())

    def __insert_node_with_fixed(self, item: int, current_node: BBNode, current_sol: ContinuousKnapsackSolution) -> None:
        fixed = current_node.fixed + [item]
        free = [j for j in current_node.free if j != item]
        self.nodes.append(BBNode(kp=self.kp, fixed=fixed, free=free, parent_sol=current_sol))

    def __insert_node_with_excluded(self, item: int, current_node: BBNode, current_sol: ContinuousKnapsackSolution) -> None:
        fixed = current_node.fixed.copy()
        free = [j for j in current_node.free if j != item]
        self.nodes.append(BBNode(kp=self.kp, fixed=fixed, free=free, parent_sol=current_sol))
    
    def solve(self) -> KnapsackSolution:
        node_n = 0

        while len(self.nodes) > 0:
            print(f"Exploring node {node_n}...")
            
            node = self.nodes.pop()
            node_n += 1
            sol = node.solve()

            # If no free item is left, the resulting KP is either
            # infeasible or completely determined (integer solution).
            assert len(node.free) > 0 or (sol is None or sol.integer())

            if sol is None:
                # Infeasible Node
                print(f"Node {node_n} infeasible.")
                continue

            if sol.integer():
                # Leaf Node
                print(f"Node {node_n} is a leaf node. Sol profit = {sol.profit}.")
                self.__update_best(sol)
                continue

            if self.best_solution is not None and sol.profit < self.best_solution.profit:
                # Sub-optimal node: prune
                print(f"Node {node_n} suboptimal. Dual bound = {sol.profit} < {self.best_solution.profit} = primal bound.")
                continue

            branching_item = min(node.free)

            print(f"Node {node_n} has a fractional optimum. Branching on item {branching_item}.")
            self.__insert_node_with_excluded(item=branching_item, current_node=node, current_sol=sol)
            self.__insert_node_with_fixed(item=branching_item, current_node=node, current_sol=sol)

        assert self.best_solution is not None

        print(f"Explored {node_n} nodes.")        
        print(f"Optimal solution: {self.best_solution}.")
        
        return self.best_solution

# %%
kp = Knapsack(weight=(2,2,2,4,4,6), profit=(5,4,3,5,4,5), capacity=12)
bb = BBTree(kp=kp)

# %%
sol = bb.solve()
# Out:
# Exploring node 0...
# 	Fixed:
# 	Excluded:
# 	Free: 0, 1, 2, 3, 4, 5
# 	Residual capacity: 12
# 	Optimal sol: 0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 0.5, 5: 0.0
# Node 1 has a fractional optimum. Branching on item 0.
# Exploring node 1...
# 	Fixed: 0
# 	Excluded:
# 	Free: 1, 2, 3, 4, 5
# 	Residual capacity: 10
# 	Branching item 0 was selected in parent node (x = 1.0): shortcutting.
# Node 2 has a fractional optimum. Branching on item 1.
# Exploring node 2...
# 	Fixed: 0, 1
# 	Excluded:
# 	Free: 2, 3, 4, 5
# 	Residual capacity: 8
# 	Branching item 1 was selected in parent node (x = 1.0): shortcutting.
# Node 3 has a fractional optimum. Branching on item 2.
# Exploring node 3...
# 	Fixed: 0, 1, 2
# 	Excluded:
# 	Free: 3, 4, 5
# 	Residual capacity: 6
# 	Branching item 2 was selected in parent node (x = 1.0): shortcutting.
# Node 4 has a fractional optimum. Branching on item 3.
# Exploring node 4...
# 	Fixed: 0, 1, 2, 3
# 	Excluded:
# 	Free: 4, 5
# 	Residual capacity: 2
# 	Branching item 3 was selected in parent node (x = 1.0): shortcutting.
# Node 5 has a fractional optimum. Branching on item 4.
# Exploring node 5...
# 	Fixed: 0, 1, 2, 3, 4
# 	Excluded:
# 	Free: 5
# 	Residual capacity: -2
# Node 6 infeasible.
# Exploring node 6...
# 	Fixed: 0, 1, 2, 3
# 	Excluded: 4
# 	Free: 5
# 	Residual capacity: 2
# 	Optimal sol: 0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 0.0, 5: 0.3333333333333333
# Node 7 has a fractional optimum. Branching on item 5.
# Exploring node 7...
# 	Fixed: 0, 1, 2, 3, 5
# 	Excluded: 4
# 	Free:
# 	Residual capacity: -4
# Node 8 infeasible.
# Exploring node 8...
# 	Fixed: 0, 1, 2, 3
# 	Excluded: 4, 5
# 	Free:
# 	Residual capacity: 2
# 	Optimal sol: 0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 0.0, 5: 0.0
# Node 9 is a leaf node. Sol profit = 17.0.
# Exploring node 9...
# 	Fixed: 0, 1, 2
# 	Excluded: 3
# 	Free: 4, 5
# 	Residual capacity: 6
# 	Branching item 3 was selected in parent node (x = 1.0): shortcutting.
# Node 10 has a fractional optimum. Branching on item 4.
# Exploring node 10...
# 	Fixed: 0, 1, 2, 4
# 	Excluded: 3
# 	Free: 5
# 	Residual capacity: 2
# 	Optimal sol: 0: 1.0, 1: 1.0, 2: 1.0, 3: 0.0, 4: 1.0, 5: 0.3333333333333333
# Node 11 suboptimal. Dual bound = 16.0 < 17.0 = primal bound.
# Exploring node 11...
# 	Fixed: 0, 1, 2
# 	Excluded: 3, 4
# 	Free: 5
# 	Residual capacity: 6
# 	Optimal sol: 0: 1.0, 1: 1.0, 2: 1.0, 3: 0.0, 4: 0.0, 5: 1.0
# Node 12 is a leaf node. Sol profit = 12.0.
# Exploring node 12...
# 	Fixed: 0, 1
# 	Excluded: 2
# 	Free: 3, 4, 5
# 	Residual capacity: 8
# 	Branching item 2 was selected in parent node (x = 1.0): shortcutting.
# Node 13 has a fractional optimum. Branching on item 3.
# Exploring node 13...
# 	Fixed: 0, 1, 3
# 	Excluded: 2
# 	Free: 4, 5
# 	Residual capacity: 4
# 	Branching item 3 was selected in parent node (x = 1.0): shortcutting.
# Node 14 has a fractional optimum. Branching on item 4.
# Exploring node 14...
# 	Fixed: 0, 1, 3, 4
# 	Excluded: 2
# 	Free: 5
# 	Residual capacity: 0
# 	Optimal sol: 0: 1.0, 1: 1.0, 2: 0.0, 3: 1.0, 4: 1.0, 5: 0.0
# Node 15 is a leaf node. Sol profit = 18.0.
# Exploring node 15...
# 	Fixed: 0, 1, 3
# 	Excluded: 2, 4
# 	Free: 5
# 	Residual capacity: 4
# 	Optimal sol: 0: 1.0, 1: 1.0, 2: 0.0, 3: 1.0, 4: 0.0, 5: 0.6666666666666666
# Node 16 suboptimal. Dual bound = 14.0 < 18.0 = primal bound.
# Exploring node 16...
# 	Fixed: 0, 1
# 	Excluded: 2, 3
# 	Free: 4, 5
# 	Residual capacity: 8
# 	Branching item 3 was selected in parent node (x = 1.0): shortcutting.
# Node 17 suboptimal. Dual bound = 17.0 < 18.0 = primal bound.
# Exploring node 17...
# 	Fixed: 0
# 	Excluded: 1
# 	Free: 2, 3, 4, 5
# 	Residual capacity: 10
# 	Branching item 1 was selected in parent node (x = 1.0): shortcutting.
# Node 18 suboptimal. Dual bound = 17.0 < 18.0 = primal bound.
# Exploring node 18...
# 	Fixed:
# 	Excluded: 0
# 	Free: 1, 2, 3, 4, 5
# 	Residual capacity: 12
# 	Branching item 0 was selected in parent node (x = 1.0): shortcutting.
# Node 19 suboptimal. Dual bound = 17.0 < 18.0 = primal bound.
# Explored 19 nodes.
# Optimal solution: Profit = 18.0; Items = 0, 1, 3, 4.
